# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from IPython import display
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd
pd.options.display.max_rows = 1000

# %% [markdown]
# # Introduction
# - In this section we are going to apply all we have learn in previous sections to work on the air pollution dataset provided by Kaggle Tabular Playground Series - Apr 2021.
# - Link: https://www.kaggle.com/c/tabular-playground-series-apr-2021
# - It is a synthetic dataset based on the famous Titantic dataset generated by GAN model (https://github.com/sdv-dev/CTGAN).
# - We will use sklearn random forest classifier to handle this problem.

# %% [markdown]
# ## Feature Definitions
# | Variable | Definition | Key |
# |---|---|---|
# | survival (target) | Survival |	0 = No, 1 = Yes |
# | pclass | Ticket class | 1 = 1st, 2 = 2nd, 3 = 3rd |
# | sex |	Sex |
# | Age |	Age in years |
# | sibsp	| # of siblings / spouses aboard the Titanic |
# | parch | # of parents / children aboard the Titanic |
# | ticket | Ticket number |
# | fare | Passenger fare |
# | cabin | Cabin number |
# | embarked | Port of Embarkation | C = Cherbourg, Q = Queenstown, S = Southampton |

# %% [markdown]
# ## Variable Notes
# - pclass: A proxy for socio-economic status (SES)
#     - 1st = Upper
#     - 2nd = Middle
#     - 3rd = Lower
# - age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# - sibsp: The dataset defines family relations in this way...
#     - Sibling = brother, sister, stepbrother, stepsister
#     - Spouse = husband, wife (mistresses and fiancés were ignored)
#
# - parch: The dataset defines family relations in this way...
#     - Parent = mother, father
#     - Child = daughter, son, stepdaughter, stepson
#     - Some children travelled only with a nanny, therefore parch=0 for them.

# %% [markdown]
# ## Train and Test Set
# - The train set contains 12 columns (including PassengerId and Name) and 100000 rows.
# - The test contains another 100000 rows.

# %% [markdown]
# ## Model Evaluation
# - It is a binary classification problem with actual values equal to 0/1. The score is <b>the percentage of passengers the model predicts correctly (accuracy)</b>.

# %% [markdown]
# ## Load Data

# %%
# load train set
df = pd.read_csv('data/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass              Name   Sex    Age  SibSp  Parch  \
# 0            0         1       1  Oconnor, Frankie  male    NaN      2      0
# 1            1         0       3       Bryan, Drew  male    NaN      0      0
# 2            2         0       3    Owens, Kenneth  male   0.33      1      2
# 3            3         0       3     Kramer, James  male  19.00      0      0
# 4            4         1       3     Bond, Michael  male  25.00      0      0
#
#       Ticket   Fare   Cabin Embarked
# 0     209245  27.14  C12239        S
# 1      27323  13.35     NaN        S
# 2  CA 457703  71.29     NaN        S
# 3   A. 10866  13.04     NaN        S
# 4     427635   7.76     NaN        S

# %% [markdown]
# # EDA
# - Before preprocessing and passing data to models, it is a good practice to visualise the dataset to spot relations among features and target.

# %% [markdown]
# ## Survival Rate

# %%
# check if the dataset is balanced
df['Survived'].value_counts().plot(kind='bar');
percent = 100*df[df['Survived'] == 1].shape[0]/df.shape[0]
print(f'Percentage of survived = {percent:.2f}%')
# Out:
# Percentage of survived = 42.77%

# %% [markdown]
# About 40% of total passengers survived.

# %% [markdown]
# ## Sex

# %%
# gender count
df.groupby('Sex')['PassengerId'].count()/df.shape[0]
# Out:
# Sex
# female    0.43886
# male      0.56114
# Name: PassengerId, dtype: float64

# %% [markdown]
# The ship contains 44% of female and 56% of male.

# %%
# survival rate of different sex
df.groupby('Sex')['Survived'].mean().plot(kind='bar');

# %% [markdown]
# 70% of female and 20% of male survived: female has more than triple of survival rate than male.

# %% [markdown]
# ## PClass and Fare

# %%
# further break down survival rate by class
df.groupby(['Sex', 'Pclass'])['Survived'].aggregate('mean').unstack().plot(kind='bar');

# %% [markdown]
# <a id='PclassFare'></a>Passengers with higher Pclass has a better chance of survival for both genders. It may actually related to Fare which determines seats or cabin.

# %%
# Pclass vs Fare
df.groupby('Pclass')[['Fare']].describe()
# Out:
#            Fare
#           count       mean        std   min    25%    50%      75%     max
# Pclass
# 1       30275.0  92.653113  99.821850  3.38  27.89  63.58  116.875  744.66
# 2       28637.0  25.756003  34.849110  1.72  10.17  22.72   29.210  613.43
# 3       40954.0  20.618226  32.621763  0.68   8.54  10.96   25.770  640.79

# %% [markdown]
# Passengers with higher Pclass paid more Fare in general.

# %%
# Survive rate vs Fare
fig, ax = plt.subplots(figsize=(10, 5))
sns.kdeplot(data=df, x='Fare', hue='Survived', ax=ax);

# %% [markdown]
# Survival rate is higher than mortality rate when Fare > 100.

# %% [markdown]
# ## Age

# %%
# age group of passengers
age = pd.cut(df['Age'], np.linspace(0, 90, 10))    # map age column to range 0-18 and 18-80 right inclusive
(age.value_counts()/df.shape[0]).plot(kind='bar');

# %% [markdown]
# The majority of passengers (~70%) aged between 20 and 60.

# %%
# age distribution by gender
g = df.groupby(['Sex', age]).count()[['PassengerId']]
g.groupby(level=0).apply(lambda x: round(100*x/float(x.sum()))).plot(kind='bar');

# %% [markdown]
# The age distributions concentrated at the middle age ranges for both gender.

# %%
# survival rate by age
df.groupby(age)['Survived'].mean().plot(kind='bar');

# %% [markdown]
# Survival rate increases with age.

# %%
# further break down by sex
df.groupby(['Sex', age])['Survived'].mean().plot(kind='bar');

# %% [markdown]
# Similar trend in survival age of both gender, except that male aged between 80-90 has a much higher survival rate.

# %%
# see what happen in male elderly
df.groupby(['Sex', age])[['PassengerId']].count().tail(1)
# Out:
#                    PassengerId
# Sex  Age
# male (80.0, 90.0]            6

# %% [markdown]
# It is because the number of male aged between 80 and 90 is extremely small, so the burst in survival rate mostly reflect nothing.

# %% [markdown]
# ## Parch and SibSp

# %%
# survival rate vs parch (# of parents/children)
sns.catplot(x='Parch', y='Survived', kind='bar', data=df);

# %%
# survival rate vs parch separated by sex (# of parents/children)
sns.catplot(x='Sex', y='Survived', hue='Parch', kind="bar", data=df);

# %% [markdown]
# People with an odd number of Parch has a higher survival rate for both genders (which is not intuitive).

# %%
# survival rate vs sibsp (# of siblings/spouses)
sns.catplot(x='SibSp', y='Survived', kind='bar', data=df);

# %%
# survival rate vs sibsp (# of siblings/spouses)
sns.catplot(x='Sex', y='Survived', hue='SibSp', kind="bar", data=df);

# %% [markdown]
# Passengers with 5 SibSp had the lowest survival rate.

# %% [markdown]
# ## Embarkment

# %%
# survival rate vs embarked (port of embarkation)
df.groupby(['Embarked'])[['Survived']].mean().plot(kind='bar');

# %% [markdown]
# The survival rate of embarkment spot C > Q > S.

# %% [markdown]
# ## Cabin

# %%
# Relation between Cabin first letter (which actually represents different deck of ship) and Pclass
# https://en.wikipedia.org/wiki/First-class_facilities_of_the_Titanic, only deck A-G for the real Titanic
def get_cabin_first_letter(x):
    try:
        return x[0]
    except:
        return 'M'    # represent missing cabin
df1 = df.copy()
df1['Deck'] = df1['Cabin'].apply(get_cabin_first_letter)
df2 = df1.groupby(['Deck', 'Pclass'])[['PassengerId']].count()
df3 = df2.groupby(level=0).apply(lambda x: round(100*x / float(x.sum()), 0)).unstack()
df3.columns = df3.columns.droplevel()
df3.plot(kind='bar', stacked=True);
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1));

# %% [markdown]
# <a id='cabineda'></a>Cabin starts with A to D are mostly for 1st class passengers, while Cabin starts with F, G and T are mostly for 2nd and 3rd class passengers.

# %%
# survival rate vs Cabin
df2 = df1.groupby(['Deck'])[['Survived']].mean()
df2['Survived'] = df2['Survived'].apply(lambda x: round(100*x))
df2['Not Survived'] = df2['Survived'].apply(lambda x: 100-x)
df2.plot(kind='bar', stacked=True);
plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1));

# %% [markdown]
# Passengers in Cabin starts with B-G had the highest survival rate (>60%), lowest survival rate at Cabin A (27%).

# %% [markdown]
# ## Ticket
# - Passengers with the same Ticket are supposed to travel together, they could be relatives/friends/maids, etc.

# %%
# TicketCount = no. of possible accompanies for each passenger
df1 = df.copy()
df1['TicketCount'] = df.groupby('Ticket')['Ticket'].transform('count')
df1.groupby('TicketCount').Survived.mean().plot(kind='bar');

# %%
df2 = df1.groupby('TicketCount')[['PassengerId']].count().reset_index()
df2['PassengerId'] = df2.apply(lambda row: int(row['PassengerId']/row['TicketCount']), axis=1)
df2.rename(columns={'PassengerId': 'No. of group'}, inplace=True)
df2
# Out:
#     TicketCount  No. of group
# 0           1.0         63398
# 1           2.0          7620
# 2           3.0          2658
# 3           4.0          1025
# 4           5.0           406
# 5           6.0           145
# 6           7.0            41
# 7           8.0            16
# 8           9.0             5
# 9          10.0             2
# 10         11.0             1
# 11         12.0             2
# 12         15.0             2
# 13         21.0             1
# 14         22.0             1
# 15         23.0             1
# 16         40.0             1
# 17         53.0             1
# 18         57.0             1
# 19         80.0             1
# 20        145.0             1
# 21        177.0             1
# 22        602.0             1

# %% [markdown]
# - TicketCount of the origin Titanic dataset ranges from 1 to 11 only, which is quite different from this dataset (has group of 4623) possibly because of the GAN model.
# - Passengers with TicketCount 23 and 4623 have higher survival rate, this can be a feature that helps to estimate target.

# %% [markdown]
# ## Name
# - Passengers with the same surname could be relatives (but can be not), so it can give us partial information of passengers' relations.
# - It can also help to clarify relations of passengers in large Ticket group.

# %%
df1 = df.copy()
df1['Surname'] = df1['Name'].apply(lambda x: x.split(', ')[0])
df1['TicketCount'] = df.groupby('Ticket')['Ticket'].transform('count')
df1.groupby(['Surname', 'TicketCount'])[['PassengerId']].count().head(100)
# Out:
#                          PassengerId
# Surname     TicketCount
# Aaberg      1.0                    1
# Aadland     1.0                    2
# Aaron       1.0                    8
#             2.0                    1
#             3.0                    1
# Aaronson    2.0                    1
# Aasen       1.0                    1
#             2.0                    1
# Abadie      1.0                    1
# Abbadessa   4.0                    1
# Abbate      1.0                    1
# Abbenante   1.0                    1
# Abbey       1.0                    2
#             5.0                    1
# Abbott      1.0                   20
#             2.0                    5
#             3.0                    2
#             4.0                    1
#             6.0                    1
# Abdelhamid  1.0                    1
# Abdi        1.0                    2
#             3.0                    1
# Abdul       3.0                    1
# ...

# %% [markdown]
# ## Correlations among features and target

# %%
# heatmap of correlation matrix
df1 = df.copy()
df1['Sex_encode'] = df1['Sex'].apply(lambda x: 1 if x =='male' else 0)
d = {'C':0, 'Q':1, 'S':2, np.nan:3}
df1['Embarked_encode'] = df1['Embarked'].apply(lambda x: d[x])
plt.figure(figsize=(8, 6))
sns.heatmap(df1.corr().round(decimals=2), annot=True, cmap='BrBG');

# %% [markdown]
# The value of pearson coefficient can be interpreted as follow:
#
# | Strength of Association |	Positive | Negative |
# |---|---|---|
# | Small | 0.1 to .3 | -0.1 to -0.3 |
# | Medium | 0.3 to .5 | -0.3 to -0.5 |
# | Large | 0.5 to 1.0 | -0.5 to -1.0 |
#
# - Large negative correlation appears between <b>Survived and Sex</b>.
# - Medium negative correlations appear between <b>Pclass and Fare</b> and between <b>Survived and Embarked</b>.

# %% [markdown]
# ## Summary of EDA
# <ol>
# <li>About 40% of total passengers survived.</li>
# <li>70% of female and 20% of male survived: female has more than triple of survival rate than male.</li>
# <li>Passengers with higher Pclass and hence paid higher Fare has a better chance of survival for both genders.</li>
# <li>The majority of passengers (~70%) aged between 20 and 60.</li>
# <li>The age distributions concentrated at the middle age ranges for both gender.</li>
# <li>Similar trend in survival age of both gender, except that male aged between 80-90 has a much higher survival rate.</li>
# <li>(Continue of 6) It is because the number of male aged between 80 and 90 is extremely small, so the burst in survival rate mostly reflect nothing.</li>
# <li>People with an odd number of Parch has a higher survival rate for both genders (which is not intuitive).</li>
# <li>Passengers with 5 SibSp had the lowest survival rate.</li>
# <li>The survival rate of embarkment spot C > Q > S.</li>
# <li>Large negative correlation appears between Survived and Sex. Medium negative correlations appear between Pclass and Fare and between Survived and Embarked.</li>
# <li>Cabin starts with A to D are mostly for 1st class passengers, while Cabin starts with F, G and T are mostly for 2nd and 3rd class passengers.</li>
# <li>Passengers in Cabin starts with B-G had the highest survival rate (>60%), lowest survival rate at Cabin A (27%).</li>
# </ol>
# - Some relations may not be seen from EDA, such as the effect of a combination of several features on survival rate. Let's move to feature engineering and apply machine learning models to recoginize such kind of implicit patterns.

# %% [markdown]
# # Filling Missing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   PassengerId  100000 non-null  int64
#  1   Survived     100000 non-null  int64
#  2   Pclass       100000 non-null  int64
#  3   Name         100000 non-null  object
#  4   Sex          100000 non-null  object
#  5   Age          96708 non-null   float64
#  6   SibSp        100000 non-null  int64
#  7   Parch        100000 non-null  int64
#  8   Ticket       95377 non-null   object
#  9   Fare         99866 non-null   float64
#  10  Cabin        32134 non-null   object
#  11  Embarked     99750 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 9.2+ MB

# %% [markdown]
# <b>Age, Ticket, Fare, Cabin and Embarked</b> have missing data.

# %% [markdown]
# ## Age
# - To fill in missing ages, the simplest way is to fill in by mean or median. If the dateset has extreme outliers (like 1% of people have yearly income \\$1 billion while others only have about \\$100k, then use median.

# %%
# age distribution
df.Age.describe()
# Out:
# count    96708.000000
# mean        38.355472
# std         18.313556
# min          0.080000
# 25%         25.000000
# 50%         39.000000
# 75%         53.000000
# max         87.000000
# Name: Age, dtype: float64

# %% [markdown]
# No outliers in age (outside 1.5 IQR). Either mean or median is good to use. We could also look deeper to Age of different groups like different Sex, Pclass, etc, to determine which median to use to fill NaN.

# %%
# check age difference for different Sex and Pclass
df.groupby(['Sex', 'Pclass'])[['Age']].median()
# Out:
#                 Age
# Sex    Pclass
# female 1       49.0
#        2       40.0
#        3       28.0
# male   1       44.0
#        2       37.0
#        3       31.0

# %% [markdown]
# So passenger with higher Pclass has higher median age, and median age of female and male are slightly absolute different (3-5).

# %%
# fill Age by median of each Sex and Pclass group
df['Age'] = df.groupby(['Sex', 'Pclass'])['Age'].apply(lambda x: x.fillna(x.median()))
df['Age'].isna().any()    # check if all nan are filled
# Out:
# False

# %% [markdown]
# ## Ticket
# - Ticket code can be a number or characters followed by number, so let's split them into two parts.

# %%
def split_ticket(x):
    try:
        if x.isdigit():
            return '', x
        char, num = x.split()
        return char, num
    except:
        return '', ''
df['TicketHead'] = df['Ticket'].apply(lambda x: split_ticket(x)[0])
df['TicketTail'] = df['Ticket'].apply(lambda x: split_ticket(x)[1])
df
# Out:
#        PassengerId  Survived  Pclass                Name     Sex    Age  \
# 0                0         1       1    Oconnor, Frankie    male  44.00
# 1                1         0       3         Bryan, Drew    male  31.00
# 2                2         0       3      Owens, Kenneth    male   0.33
# 3                3         0       3       Kramer, James    male  19.00
# 4                4         1       3       Bond, Michael    male  25.00
# ...            ...       ...     ...                 ...     ...    ...
# 99995        99995         1       2         Bell, Adele  female  62.00
# 99996        99996         0       2       Brown, Herman    male  66.00
# 99997        99997         0       3  Childress, Charles    male  37.00
# 99998        99998         0       3    Caughlin, Thomas    male  51.00
# 99999        99999         0       3       Enciso, Tyler    male  55.00
#
#        SibSp  Parch     Ticket   Fare   Cabin Embarked TicketHead TicketTail
# ...

# %%
df['TicketHead'].unique()
# Out:
# array(['', 'CA', 'A.', 'A/S', 'PC', 'W./C.', 'SC/PARIS', 'S.C./PARIS',
#        'SC/Paris', 'CA.', 'SOTON/O.Q.', 'C.A.', 'A/5.', 'STON/O', 'A/4',
#        'C', 'AQ/4', 'STON/O2.', 'WE/P', 'F.C.', 'F.C.C.', 'PP', 'S.O.C.',
#        'SC/AH', 'Fa', 'W.E.P.', 'C.A./SOTON', 'P/PP', 'A/5', 'SOTON/O2',
#        'SW/PP', 'STON/OQ.', 'W/C', 'S.O./P.P.', 'SC', 'A./5.', 'A/4.',
#        'S.O.P.', 'SOTON/OQ', 'SO/C', 'SCO/W', 'A.5.', 'S.W./PP', 'S.P.',
#        'LP', 'SC/A4', 'AQ/3.', 'S.C./A.4.', 'A4.', 'SC/A.3'], dtype=object)

# %%
df.groupby('Ticket')[['PassengerId']].count().sort_index().sort_values(by='PassengerId', ascending=False).head(100)
# Out:
#              PassengerId
# Ticket
# A/5                  602
# C.A.                 177
# SC/PARIS             145
# SOTON/O.Q.            80
# SC                    57
# W./C.                 53
# A/5.                  40
# W.E.P.                23
# CA                    22
# STON/O2.              21
# CA.                   15
# PP                    15
# A/4                   12
# LP                    12
# SOTON/OQ              11
# S.P.                  10
# 9566                  10
# S.O.C.                 9
# 12736                  9
# 9627                   9
# PC                     9
# 12198                  9
# 10362                  8
# 11395                  8
# 9974                   8
# 11924                  8
# 10427                  8
# 10103                  8
# 12255                  8
# 10304                  8
# 10867                  8
# 11066                  8
# 11042                  8
# 11538                  8
# 11193                  8
# ...

# %%
df.groupby(['TicketHead', 'Pclass']).count()
# Out:
#                    PassengerId  Survived   Name    Sex    Age  SibSp  Parch  \
# TicketHead Pclass
#            1             21469     21469  21469  21469  21469  21469  21469
#            2             23579     23579  23579  23579  23579  23579  23579
#            3             31668     31668  31668  31668  31668  31668  31668
# A.         1                11        11     11     11     11     11     11
#            2               986       986    986    986    986    986    986
#            3              2753      2753   2753   2753   2753   2753   2753
# A./5.      1                29        29     29     29     29     29     29
#            2                30        30     30     30     30     30     30
#            3                47        47     47     47     47     47     47
# A.5.       1                11        11     11     11     11     11     11
#            2                20        20     20     20     20     20     20
# ...

# %% [markdown]
# No obvious pattern can be seen from Ticket, let's just fill NaN by empty string first.

# %%
df['Ticket'] = df['Ticket'].fillna('')
df['Ticket'].isna().any()
# Out:
# False

# %% [markdown]
# ## Fare
# - As we saw in <a href='#PclassFare'>EDA</a> that Fare is related to Pclass, we better fill missing Fare according to Pclass. But let's look at the difference of Fare with other features as well.

# %%
df.groupby(['Pclass', 'Sex'])[['Fare']].median()
# Out:
#                  Fare
# Pclass Sex
# 1      female  71.620
#        male    50.320
# 2      female  25.100
#        male    14.005
# 3      female  13.690
#        male    10.390

# %% [markdown]
# Fare of female is more expenisve than that of male in the same Pclass.

# %%
df['FamilySize'] = df.apply(lambda row: row['SibSp']+row['Parch'], axis=1)
df.groupby(['Pclass', 'Sex', 'FamilySize'])[['Fare']].median()
# Out:
#                              Fare
# Pclass Sex    FamilySize
# 1      female 0            72.230
#               1            73.800
#               2            68.565
#               3            72.060
#               4            68.245
#               5            63.300
#               6            57.705
#               7            62.490
#               8            68.500
#               9            51.825
#               10           62.630
#               11           58.860
#               12           29.680
#        male   0            31.065
#               1            59.110
#               2            61.470
#               3            68.340
#               4            59.260
#               5            62.210
#               6            32.945
#               7            60.720
#               8            65.140
#               9            30.210
#               10           68.650
#               12          333.200
# 2      female 0            17.750
# ...

# %% [markdown]
# Individual Fare seems does not related to family size.

# %%
# fill Fare by median of each Sex and Pclass group
df['Fare'] = df.groupby(['Sex', 'Pclass'])['Fare'].apply(lambda x: x.fillna(x.median()))
df['Fare'].isna().any()    # check if all nan are filled
# Out:
# False

# %% [markdown]
# ## Cabin
# - ~68% of Cabin data are missing, similar to EDA above we just fill them as M.

# %%
df['Cabin'] = df['Cabin'].fillna('M')
df['Deck'] = df['Cabin'].apply(lambda x: x[0])
df['Deck'].isna().any()
# Out:
# False

# %% [markdown]
# ## Embarked
# - Since the number of missing Embarked accounts for 0.25% of data, so we just fill in by mode.

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df['Embarked'].isna().any()
# Out:
# False

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Name
# - Split Name into first name and last name to identify possible relationships of family members

# %%
df['Surname'] = df['Name'].apply(lambda x: x.split(', ')[0])

# %% [markdown]
# ## Age (Test if need binning)

# %%
# from sklearn.preprocessing import LabelEncoder
# df['AgeBinned'] = df['Age'].apply(lambda x: round(x, -1))
# le = LabelEncoder()
# df['AgeBinned'] = le.fit_transform(df['AgeBinned'])

# %% [markdown]
# ## SibSp and Parch
# - We create a new feature named FamilySize by adding SibSp and Parch.

# %%
df['FamilySize'] = df.apply(lambda row: row['SibSp']+row['Parch']+1, axis=1)
df['FamilySize'].describe()
# Out:
# count    100000.000000
# mean          1.852250
# std           1.412792
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max          18.000000
# Name: FamilySize, dtype: float64

# %% [markdown]
# ## Ticket
# - As in EDA, we generate new feature <b>TicketCount</b> which helps to identify passenger group.
# - We also keep <b>TicketHead</b> and <b>TicketTail</b> as features.

# %%
df['TicketCount'] = df.groupby('Ticket')['Ticket'].transform('count')
df['TicketCount'].describe()
# Out:
# count    100000.000000
# mean        219.564660
# std         970.626174
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max        4623.000000
# Name: TicketCount, dtype: float64

# %%
df['TicketTail'] = df['TicketTail'].apply(lambda x: int(x) if x!='' else 0)

# %% [markdown]
# ## Fare (Test if need binning)

# %%
# df['FareBinned'] = pd.qcut(df['Fare'], q=10)
# df['FareBinned'] = le.fit_transform(df['FareBinned'])

# %% [markdown]
# ## Cabin
# - As in filling missing data, we have already derived a new feature <b>Deck</b> from the first letter of Cabin, and transform it into <b>one-hot encoding</b>.
# - We keep the last part of Cabin as <b>CabinNumber</b> as some passengers share the same CabinNumber.

# %%
df['Deck'] = df['Cabin'].apply(lambda x: x[0])

# %%
df['CabinNumber'] = df['Cabin'].apply(lambda x: int(x[1:]) if x[1:]!='' else 0)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'TicketHead',
#        'TicketTail', 'FamilySize', 'Deck', 'Surname', 'TicketCount',
#        'CabinNumber'],
#       dtype='object')

# %% [markdown]
# ## One-hot Encoding
# - Decision tree models implemented by sklearn can only accepts numerical inputs (theoretically decision tree can handle categorical inputs directly), we have to convert categorical data into numeric by <b>one-hot encoding</b> before passing them to the model.
# - Categorical features we have: Sex, Surname, TicketHead, TicketTail, Deck, CabinNumber, Embarked

# %%
# %%time 
onehot = pd.get_dummies(df[['Sex', 'Surname', 'TicketHead', 'Deck', 'Embarked']])
features = df[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'FamilySize', 'TicketCount', 'TicketTail', 'CabinNumber']].join(onehot)
len(features.columns)
# Out:
# Wall time: 1min 26s
# 21631

# %%
# %%time 
# onehot = pd.get_dummies(df[['Sex', 'Embarked', 'TicketHead', 'Deck', 'Surname']])
# features = df[['Pclass', 'SibSp', 'Parch', 'FamilySize', 'TicketCount', 'AgeBinned', 'FareBinned']].join(onehot)
# len(features.columns)

# %% [markdown]
# There is a total of 21629 features after one-hot encoding, which is a bit too much for model to process. Let's perform PCA we have learnt before to select important features.

# %% [markdown]
# # Random Forest Classification

# %%
# split data
from sklearn.model_selection import train_test_split
size = 10000    # size of data used
X = features[:size]
y = df['Survived'][:size]
X.shape
# Out:
# (10000, 21631)

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
model = RandomForestClassifier(random_state=0)
scores = cross_val_score(model, X, y, cv=5)
np.mean(scores)
# age continuous .770
# age binned categorical .767
# age, fare binned label encode .765
# size=1000, time 31.8s
# size=5000, time 225s
# size=10000, time 460s
# size=10000 with pca, time 20.9s, acc .736
# size=10000 without pca, time 4.51s, acc .752
# size=100000 without pca, time 76s, acc .751
# size=10000, time 411s, acc .769
# Out:
# Wall time: 7min 36s
# 0.7691999999999999

# %% [markdown]
# From experiments the estimated time to run a 5-fold cv could be ~5000s which is more than an hour, so for simplicity we only work on 1/10 of the data here.

# %% [markdown]
# # Hyperparameter Tuning
# - Perform grid search cv on hyperparameters of decision tree

# %%
# get list of parameters of random forest model
from pprint import pprint
pprint(model.get_params())
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Consider the following hyperparmeters:
# - n_estimators = no. of trees in the forest
# - max_features = max no. of features to consider when choosing the best split
# - max_depth = max no. of levels in each tree
# - min_samples_split = min no. of samples required to split an internal node
# - min_samples_leaf = min no. of samples required to be a leaf node
# - bootstrap = if True, use bootstrap sampling to build a tree (sample with replacement), otherwise use all data for each tree (still has random nature in the model with random subset of features to choose in each node)
# - max_samples = if bootstrape = True, the no. of samples draw for each tree

# %%
# ~no. of splits per tree if split evenly, reference for max_depth
int(np.log(10000)/np.log(2))
# Out:
# 13

# %%
# %%time
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],                  # default = 100
    'criterion': ['gini', 'entropy'],                # default = gini
    'max_depth': [None, 5, 10, 20],                  # default = None
    'max_features': ['sqrt', 'log2'],                # default = None = sqrt
    'min_samples_leaf': [1, 2, 4],                   # default = 1
    'min_samples_split': [2, 4, 8],                  # default = 2
    'bootstrap': [True, False],                      # default = True
    'max_samples': [None, .3, .6, .9]                # default None, draw X.shape[0] samples for each tree
}
grid = GridSearchCV(model, param_grid, cv=5)
# grid.fit(X, y)
# Out:
# Wall time: 0 ns

# %%
# number of parameter set to try
num_parameter_set = [len(x) for x in param_grid.values()]
np.prod(num_parameter_set)
# Out:
# 3456

# %% [markdown]
# As the dataset is not small and the number of sets of parameters is huge, for demonstration we use random search to search over 50 sets of hyparameter.

# %%
# %%time
from sklearn.model_selection import RandomizedSearchCV
search = RandomizedSearchCV(
    estimator = model, 
    param_distributions = param_grid,
    n_iter = 50,
    random_state=0,
    cv=5
)
search.fit(X, y)
# 20 sets: 195s
# 50 sets: 2400s
# Out:
# Wall time: 40min 15s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0),
#                    n_iter=50,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 5, 10, 20],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'max_samples': [None, 0.3, 0.6, 0.9],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 4, 8],
#                                         'n_estimators': [50, 100, 200]},
#                    random_state=0)

# %%
# best parameters
search.best_params_
# Out:
# {'n_estimators': 200,
#  'min_samples_split': 8,
#  'min_samples_leaf': 1,
#  'max_samples': 0.3,
#  'max_features': 'sqrt',
#  'max_depth': None,
#  'criterion': 'entropy',
#  'bootstrap': True}

# %%
# mean score of best parameters
search.best_score_
# Out:
# 0.7753999999999999

# %% [markdown]
# Attain an accuracy of 78% after hyperparameter tunning, which gives around 1% improvement. It is expected that grid search would give better improvement if one have more computation power.
